# %% [markdown]
# <a href="https://colab.research.google.com/github/blackartus/data-sciense-bootcamp/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("FirstLine")
# Out:
# FirstLine
